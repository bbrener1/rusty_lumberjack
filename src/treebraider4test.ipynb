# %%
import lumberjack
import tree_reader as tr

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = np.loadtxt('../testing/iris.trunc')

# %%
iris_forest = lumberjack.save_trees('../testing/iris_forest/run',iris,in_feature_subsample=2,out_feature_subsample=2,ss=100,trees=200,)
# Out:
# Generating trees
# Running /Users/boris/taylor/vision/rust_prototype/rusty_lumberjack/target/release/lumberjack_1
# Command: /Users/boris/taylor/vision/rust_prototype/rusty_lumberjack/target/release/lumberjack_1 generate -ic ../testing/iris_forest/runinput.counts -oc ../testing/iris_forest/runoutput.counts -o ../testing/iris_forest/runtmp -auto -ifh ../testing/iris_forest/runtmp.ifh -ofh ../testing/iris_forest/runtmp.ofh -in_feature_subsample 2 -out_feature_subsample 2 -ss 100 -trees 200
# Trying to readline
#
# 5.1 0
# 100
# ...
# 150,4
#
# 5.1 0
# 100
# ...
# 150,4
# Automatic parameters:
# ss:100
# if:4
# of:4
# p:8
# t:100
# l:10
# d:No
# pm:Branch
# Reading header: ../testing/iris_forest/runtmp.ifh
# Read 4 lines
# Reading header: ../testing/iris_forest/runtmp.ofh
# Read 4 lines
# Parsed parameters (Otherwise /function/ default)
# ...
